# %%
import pandas as pd

# %% [markdown]
# ## Read in all the 2018 CSVs, check dates

# %%
# Categories: DayOfWeek, FlightDate, Reporting_Airline, Tail_Number
# OriginAirportID, Origin, OriginCityName, OriginState
# DestAirportID, Dest, DestCityName, DestState, DepTime, DepDelay
# ArrDelay, CarrierDelay, WeatherDelay, NASDelay, SecurityDelay, LateAircraftDelay
df18_1 = pd.read_csv('data/jan_2018.csv')
df18_2 = pd.read_csv('data/feb_2018.csv')
df18_3 = pd.read_csv('data/march_2018.csv')
df18_4 = pd.read_csv('data/april_2018.csv')
df18_5 = pd.read_csv('data/may_2018.csv')
df18_6 = pd.read_csv('data/june_2018.csv')
df18_7 = pd.read_csv('data/july_2018.csv')
df18_8 = pd.read_csv('data/aug_2018.csv')
df18_9 = pd.read_csv('data/sept_2018.csv')

# %%
# df18_5.head()

# %% [markdown]
# ## Read in 2017 CSVs

# %%
df17_1 = pd.read_csv('data/jan_2017.csv')
df17_2 = pd.read_csv('data/feb_2017.csv')
df17_3 = pd.read_csv('data/march_2017.csv')
df17_4 = pd.read_csv('data/april_2017.csv')
df17_5 = pd.read_csv('data/may_2017.csv')
df17_6 = pd.read_csv('data/june_2017.csv')
df17_7 = pd.read_csv('data/july_2017.csv')
df17_8 = pd.read_csv('data/aug_2017.csv')
df17_9 = pd.read_csv('data/sept_2017.csv')
df17_10 = pd.read_csv('data/oct_2017.csv')
df17_11 = pd.read_csv('data/nov_2017.csv')
df17_12 = pd.read_csv('data/dec_2017.csv')

# %%
# df17_12.head()

# %% [markdown]
# ## Read in 2016 CSVs

# %%
df16_1 = pd.read_csv('data/jan_2016.csv')
df16_2 = pd.read_csv('data/feb_2016.csv')
df16_3 = pd.read_csv('data/march_2016.csv')
df16_4 = pd.read_csv('data/april_2016.csv')
df16_5 = pd.read_csv('data/may_2016.csv')
df16_6 = pd.read_csv('data/june_2016.csv')
df16_7 = pd.read_csv('data/july_2016.csv')
df16_8 = pd.read_csv('data/aug_2016.csv')
df16_9 = pd.read_csv('data/sept_2016.csv')
df16_10 = pd.read_csv('data/oct_2016.csv')
df16_11 = pd.read_csv('data/nov_2016.csv')
df16_12 = pd.read_csv('data/dec_2016.csv')

# %%
# df16_12.head()

# %% [markdown]
# ## Read in 2015 CSVs

# %%
df15_1 = pd.read_csv('data/jan_2015.csv')
df15_2 = pd.read_csv('data/feb_2015.csv')
df15_3 = pd.read_csv('data/march_2015.csv')
df15_4 = pd.read_csv('data/april_2015.csv')
df15_5 = pd.read_csv('data/may_2015.csv')
df15_6 = pd.read_csv('data/june_2015.csv')
df15_7 = pd.read_csv('data/july_2015.csv')
df15_8 = pd.read_csv('data/aug_2015.csv')
df15_9 = pd.read_csv('data/sept_2015.csv')
df15_10 = pd.read_csv('data/oct_2015.csv')
df15_11 = pd.read_csv('data/nov_2015.csv')
df15_12 = pd.read_csv('data/dec_2015.csv')

# %%
# df15_12.head()

# %% [markdown]
# ## Join the separate months into a full dataframe for all of 2018

# %%
df18 = pd.concat([df18_1, df18_2, df18_3, df18_4, df18_5, df18_6, df18_7, df18_8, df18_9], sort=True)
df18.head()
# Out:
#    ARR_DELAY  CARRIER_DELAY  DAY_OF_WEEK  DEP_DELAY  DEP_TIME DEST  \
# 0       26.0            0.0            1       44.0    1400.0  SFO
# 1      -13.0            NaN            1       -7.0    1328.0  DEN
# 2       -4.0            NaN            1       -6.0    1609.0  ORD
# 3       -4.0            NaN            1        0.0    2103.0  LGA
# 4       -9.0            NaN            1       -8.0     727.0  LAS
#
#    DEST_AIRPORT_ID     DEST_CITY_NAME DEST_STATE_ABR     FL_DATE  \
# 0            14771  San Francisco, CA             CA  2018-01-22
# 1            11292         Denver, CO             CO  2018-01-22
# 2            13930        Chicago, IL             IL  2018-01-22
# 3            12953       New York, NY             NY  2018-01-22
# 4            12889      Las Vegas, NV             NV  2018-01-22
#
#        ...        NAS_DELAY  OP_UNIQUE_CARRIER ORIGIN ORIGIN_AIRPORT_ID  \
# 0      ...              0.0                 UA    LAS             12889
# ...

# %% [markdown]
# ## Join all of 2017

# %%
df17 = pd.concat([df17_1, df17_2, df17_3, df17_4, df17_5, df17_6, df17_7, df17_8, df17_9, df17_10, df17_11, df17_12], sort=True)
df17
# Out:
#         ARR_DELAY  CARRIER_DELAY  DAY_OF_WEEK  DEP_DELAY  DEP_TIME DEST  \
# 0            12.0            NaN            1       -3.0     757.0  LAX
# 1           158.0          158.0            1      169.0    1049.0  LAX
# 2            13.0            NaN            1       -2.0     758.0  LAX
# 3            -5.0            NaN            1       -2.0     758.0  LAX
# 4           -56.0            NaN            1      -10.0     750.0  LAX
# 5            -3.0            NaN            1       -5.0     855.0  JFK
# 6            25.0            0.0            1       -1.0     859.0  JFK
# 7           -18.0            NaN            1       -1.0     859.0  JFK
# 8            24.0            0.0            1       -7.0     853.0  JFK
# 9           -12.0            NaN            1      -10.0     850.0  JFK
# 10            4.0            NaN            1       10.0    1210.0  LAX
# 11          -50.0            NaN            1       -9.0    1151.0  LAX
# ...

# %% [markdown]
# ## Now let's join 2016

# %%
df16 = pd.concat([df16_1, df16_2, df16_3, df16_4, df16_5, df16_6, df16_7, df16_8, df16_9, df16_10, df16_11, df16_12], sort=True)
df16
# Out:
#         ARR_DELAY  CARRIER_DELAY  DAY_OF_WEEK  DEP_DELAY  DEP_TIME DEST  \
# 0            -2.0            NaN            1       -2.0     728.0  FLL
# 1           -11.0            NaN            1        3.0    1323.0  MSP
# 2             5.0            NaN            1       -1.0     559.0  DTW
# 3           -13.0            NaN            1       -2.0     558.0  ATL
# 4             1.0            NaN            1       18.0     743.0  ATL
# 5            -5.0            NaN            1       -6.0     829.0  LAS
# 6           -29.0            NaN            1       -2.0    1123.0  GEG
# 7             6.0            NaN            1       -3.0    1322.0  MSP
# 8            -7.0            NaN            1       -4.0    1946.0  MCO
# 9             5.0            NaN            1       25.0    1310.0  LGA
# 10          -11.0            NaN            1        1.0     816.0  MCO
# 11          -15.0            NaN            1        4.0    1344.0  IAH
# ...

# %% [markdown]
# ## And finally, 2015

# %%
df15 = pd.concat([df15_1, df15_2, df15_3, df15_4, df15_5, df15_6, df15_7, df15_8, df15_9, df15_10, df15_11, df15_12], sort=True)
df15
# Out:
#         ARR_DELAY  CARRIER_DELAY  DAY_OF_WEEK  DEP_DELAY  DEP_TIME DEST  \
# 0           -11.0            NaN            1        8.0     708.0  LAS
# 1            22.0           22.0            1       22.0     722.0  LAS
# 2           -12.0            NaN            1       -6.0     654.0  LAS
# 3           -16.0            NaN            1       -6.0     654.0  LAS
# 4            -4.0            NaN            1        1.0    2149.0  FLL
# 5            10.0            NaN            1        9.0    2157.0  FLL
# 6           -13.0            NaN            1      -10.0    2138.0  FLL
# 7             1.0            NaN            1       -2.0    2146.0  FLL
# 8             8.0            NaN            1        5.0    1055.0  FLL
# 9            14.0            NaN            1       26.0    1116.0  FLL
# 10          -35.0            NaN            1        0.0    1050.0  FLL
# 11           97.0           59.0            1       59.0    1149.0  FLL
# ...

# %% [markdown]
# ## Most Delayed Flights by origin and destination
# ### Grouped by the Origin and Destination airports, plus the average delay time for each route

# %%
df18.groupby(['ORIGIN','DEST'], as_index=False)['DEP_DELAY'].mean().sort_values(by='DEP_DELAY', ascending=False)
# Out:
#      ORIGIN DEST    DEP_DELAY
# 1927    ESC  MQT  1048.000000
# 4910    RDM  MFR   814.000000
# 3454    MDT  HPN   759.000000
# 1739    DSM  CID   295.000000
# 2244    GRB  MQT   257.000000
# 1904    ELM  ATL   194.000000
# 2648    ICT  DAY   181.000000
# 4       ABE  MDT   175.000000
# 1924    ERI  ITH   156.000000
# 1757    DSM  PIA   155.000000
# 1123    CMH  HOU   148.000000
# 383     AVL  TPA   147.250000
# 1174    CRP  BRO   147.000000
# 2802    JAX  TPA   144.000000
# 3134    LBB  SAF   134.000000
# 5891    SWF  PBI   122.000000
# 391     AVP  SFB   113.000000
# 1917    ELP  OKC   112.000000
# 6151    YNG  PIE   111.000000
# 6060    TVC  EWR   104.217949
# 3872    MSP  PVD   102.000000
# 2314    GTF  BZN   101.000000
# 1172    CPR  LAS   100.000000
# 4751    PIE  YNG    89.000000
# 2651    ICT  HYS    88.000000
# 2435    HRL  DAL    86.000000
# 2932    LAS  CPR    81.000000
# 98      ANC  DFW    80.043103
# 2478    IAD  GSO    79.666667
# 4977    RIC  BNA    78.413793
# ...

# %% [markdown]
# ## Earliest departure flights, by origin and destination
# ### Grouped by origin and destination, with an average of the delay time

# %%
df18.groupby(['ORIGIN','DEST'], as_index=False)['DEP_DELAY'].mean().sort_values(by='DEP_DELAY', ascending=True)
# Out:
#      ORIGIN DEST    DEP_DELAY
# 5563    SIT  ANC   -22.000000
# 4805    PNS  CLL   -15.000000
# 3757    MSN  STL   -15.000000
# 1313    DAY  MYR   -13.538462
# 3737    MSN  CLE   -13.500000
# 6150    YAK  JNU   -12.192593
# 5293    SDF  TXK   -11.000000
# 3963    MTJ  SLC   -10.285714
# 2170    FNT  MYR   -10.181818
# 1876    EAR  DEN   -10.162791
# 6129    WRG  KTN   -10.140741
# 2336    HDN  SFO   -10.083333
# 4069    OGG  BLI   -10.038462
# 4261    ORD  LFT   -10.000000
# 4056    OAK  PVU   -10.000000
# 1750    DSM  LIT   -10.000000
# 2494    IAD  MSN    -9.500000
# 3735    MSN  BNA    -9.500000
# 4833    PSG  WRG    -9.420664
# 2899    KTN  JNU    -9.236052
# 1735    DRO  LAX    -9.230769
# 2308    GSP  PGD    -9.000000
# 3745    MSN  IAH    -9.000000
# 2049    FAI  ANC    -8.863300
# 5255    SCC  BRW    -8.700000
# 695     BRW  ANC    -8.033582
# 6008    TTN  PIE    -8.000000
# 861     CDV  YAK    -7.415441
# 5869    STT  EWR    -7.400000
# 2879    JNU  KTN    -7.333333
# ...

# %% [markdown]
# ## Most delayed flights by origin, destination, and airline
# ### Grouped by Origin Airport, Destination, and Airline, with an average of the delay times

# %%
df18.groupby(['ORIGIN','DEST', 'OP_UNIQUE_CARRIER'], as_index=False)['DEP_DELAY'].mean().sort_values(by='DEP_DELAY', ascending=False)
# Out:
#       ORIGIN DEST OP_UNIQUE_CARRIER    DEP_DELAY
# 4023     ESC  MQT                OO  1048.000000
# 1453     BUF  LGA                OO   853.000000
# 6539     LGA  BOS                OO   851.000000
# 10127    RDM  MFR                OO   814.000000
# 7183     MDT  HPN                EV   759.000000
# 3941     DTW  TUL                EV   435.500000
# 9757     PHX  TUL                F9   400.000000
# 1268     BOS  LGA                OO   323.500000
# 7808     MSP  DFW                YX   300.000000
# 3566     DSM  CID                EV   295.000000
# 4642     GRK  ATL                EV   279.000000
# 4629     GRB  MQT                OO   257.000000
# 1100     BNA  MSP                EV   255.500000
# 2236     CMH  LGA                DL   254.000000
# 8903     ORD  ORF                AA   239.125000
# 281      ATL  CVG                EV   226.000000
# 1892     CLE  ORD                F9   217.000000
# 2345     CVG  ATL                EV   216.000000
# ...

# %% [markdown]
# ## Least delayed flights by origin, destination, and airline
# ### Grouped by Origin Airport, Destination, and Airline, with an average of the delay times

# %%
df18.groupby(['ORIGIN','DEST', 'OP_UNIQUE_CARRIER'], as_index=False)['DEP_DELAY'].mean().sort_values(by='DEP_DELAY', ascending=True)
# Out:
#       ORIGIN DEST OP_UNIQUE_CARRIER    DEP_DELAY
# 11361    SIT  ANC                AS   -22.000000
# 7687     MSN  STL                9E   -15.000000
# 9947     PNS  CLL                EV   -15.000000
# 4302     FAR  DFW                DL   -14.000000
# 7685     MSN  SLC                DL   -14.000000
# 2574     DAY  MYR                G4   -13.538462
# 7646     MSN  CLE                EV   -13.500000
# 12187    TVC  EWR                YX   -13.000000
# 12331    YAK  JNU                AS   -12.192593
# 6569     LGA  CMH                DL   -12.000000
# 8190     MYR  BOS                9E   -12.000000
# 8192     MYR  BOS                YX   -11.750000
# 10865    SDF  TXK                EV   -11.000000
# 11929    SYR  ORD                EV   -11.000000
# 7671     MSN  MSP                EV   -11.000000
# 8177     MTJ  SLC                OO   -10.285714
# 8308     OAK  PDX                AS   -10.226277
# 4510     FNT  MYR                G4   -10.181818
# ...

# %% [markdown]
# ## Group by Origin, Destination, and Date to find potential bad weather days

# %%
df18.groupby(['ORIGIN','DEST', 'FL_DATE'], as_index=False)['DEP_DELAY'].mean().sort_values(by='DEP_DELAY', ascending=False)
# Out:
#         ORIGIN DEST     FL_DATE  DEP_DELAY
# 514896     HNL  PPG  2018-02-09     2482.0
# 1030031    PPG  HNL  2018-02-09     2468.0
# 422134     EGE  JFK  2018-01-11     2007.0
# 511824     HNL  JFK  2018-01-03     1682.0
# 422370     EGE  MIA  2018-03-04     1552.0
# 143314     BQN  JFK  2018-01-06     1489.0
# 767486     MEI  ORD  2018-01-03     1424.0
# 373123     DFW  PIB  2018-01-03     1416.0
# 944051     PBI  ACY  2018-04-05     1394.0
# 23750      ASE  DFW  2018-06-02     1370.0
# 422348     EGE  MIA  2018-02-10     1366.0
# 597501     ITO  LAX  2018-06-14     1363.0
# 1045970    RDM  PHX  2018-04-27     1337.0
# 511158     HNL  IAD  2018-03-30     1333.0
# 597362     ITO  LAX  2018-01-26     1313.0
# 456095     FAR  MSP  2018-04-14     1308.0
# 780427     MHT  ORD  2018-01-22     1297.0
# 583552     IMT  DTW  2018-05-16     1288.0
# 1116209    SDF  DTW  2018-01-12     1283.0
# 348065     DFW  BZN  2018-05-04     1273.0
# 513608     HNL  OAK  2018-03-31     1260.0
# ...

# %% [markdown]
# ## Weather delays again, but this time using the WEATHER_DELAY column

# %%
# Fill NaNs as zeros so the weather delay column averages properly
df18.fillna(0).groupby(['ORIGIN','DEST', 'FL_DATE'], as_index=False)['WEATHER_DELAY'].mean().sort_values(by='WEATHER_DELAY', ascending=False)
# Out:
#         ORIGIN DEST     FL_DATE  WEATHER_DELAY
# 514896     HNL  PPG  2018-02-09         2475.0
# 511824     HNL  JFK  2018-01-03         1682.0
# 583552     IMT  DTW  2018-05-16         1287.0
# 1156992    SFO  MMH  2018-02-11         1203.0
# 583691     IMT  MSP  2018-01-22         1186.0
# 622013     JFK  SAT  2018-05-15         1100.0
# 813499     MSN  EWR  2018-03-05         1078.0
# 594023     INL  MSP  2018-05-29         1030.0
# 305891     DCA  SLC  2018-03-02          993.0
# 560753     IAH  GSP  2018-01-11          970.0
# 262663     CVG  MKE  2018-05-15          956.0
# 1034141    PSP  MSP  2018-01-22          953.0
# 1209779    SLN  ORD  2018-06-22          951.0
# 904181     ORD  CKB  2018-06-19          944.0
# 8456       ACK  LGA  2018-07-17          940.0
# 546769     IAD  PWM  2018-06-02          931.0
# 1048790    RDU  CMH  2018-05-11          926.0
# 1189333    SLC  BTM  2018-02-17          916.0
# 711106     LIT  DEN  2018-06-24          910.0
# ...
